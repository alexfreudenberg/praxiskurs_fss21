# %%
setwd("~//praxiskurs_fss21/")
options(repr.plot.width=8, repr.plot.height=3,repr.plot.res = 300)

# %%
df_covid <- read.csv("data/RKI_COVID19.csv")

# %%
runmax <- function()0
help(runmax)

# %%
df_covid$Meldedatum <- as.Date(df_covid$Meldedatum)
dates <- seq(min(df_covid$Meldedatum)-3, max(df_covid$Meldedatum), by="day") 
df_complete  <- data.frame(dates = dates )
df_complete$cases_per_day <- sapply(dates, function(date) sum(df_covid$AnzahlFall[df_covid$Meldedatum == date])  )
df_complete$runmean_cases <- caTools::runmean(df_complete$cases_per_day, k=7, align="center")
df_complete$deaths_per_day <- sapply(dates, function(date) sum(df_covid$AnzahlTodesfall[df_covid$Meldedatum == date])  )
df_complete$runmean_deaths <- caTools::runmean(df_complete$deaths_per_day, k=7, align="center")
df_complete <- df_complete[dates<=max(df_covid$Meldedatum),]

# %%
library(ggplot2)
p <- ggplot(df_complete) +
    geom_path(aes(x=dates, y=cases_per_day),color="grey") + 
    geom_path(aes(x=dates, y=3, color= runmean_cases)) +
    scale_color_viridis_c() +
    scale_x_date(breaks=seq(min(dates),max(dates),by="3 months")) 
p
# Out:
# Error in ggplot(df_complete): Objekt 'df_complete' nicht gefunden
# Traceback:
#
# 1. ggplot(df_complete)

# %% [markdown]
# # Exponentielles Wachstum

# %%
p + scale_x_date(breaks=seq(min(dates),max(dates),by="2 weeks"), 
                    limits=c(as.Date("2020-08-01"),as.Date("2020-11-15")))
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
#
# Warning message:
# "Removed 375 row(s) containing missing values (geom_path)."
# Warning message:
# "Removed 375 row(s) containing missing values (geom_path)."
# plot without title

# %%
date_limits <- c(as.Date("2020-09-12"),as.Date("2020-10-27"))
q <- p + scale_x_date(breaks=seq(min(dates),max(dates),by="2 weeks"), limits= date_limits) +
    scale_y_log10(limits=c(300,20000))
q
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
#
# Warning message:
# "Transformation introduced infinite values in continuous y-axis"
# Warning message:
# "Transformation introduced infinite values in continuous y-axis"
# Warning message:
# "Removed 436 row(s) containing missing values (geom_path)."
# Warning message:
# "Removed 436 row(s) containing missing values (geom_path)."
# plot without title

# %% [markdown]
# Angenommen, wir haben im obigen Zeitraum ein exponentielles Wachstum, dann sollte für $a,b>0$ gelten
# \\[ y \approx e^{a t + b}\\]
# für die Zeitvariable $t$. Wir versuchen nun den Intercept $b$ und den Slope $a$ zu schätzen. Dafür beobachten wir zunächst
# \\[ \log(y) = at+b.\\]
# Für einen Vektor $(z_1,...,z_n)^T=\log(y)$ ist eine mögliche Schätzung also
# \\[ a=z_1, \quad b=(z_n-z_1)/n.\\]

# %%
y_diff <- log(df_complete$runmean_cases[df_complete$dates %in% date_limits])
intercept  <- y_diff[1]
y_diff <- y_diff[2]-y_diff[1]
x_diff <- (date_limits[2]-date_limits[1])

# %%
intercept
# Out:
# [1] 7.309881

# %%
str(x_diff)
# Out:
#  'difftime' num 45
#  - attr(*, "units")= chr "days"

# %%
slope <- y_diff/as.numeric(x_diff)
slope
# Out:
# [1] 0.05126158

# %%
line <-exp( (0:45) * slope + intercept)
df_line <- data.frame(dates= seq(date_limits[1],date_limits[2], by = "1 day"),line=line)
head(df_line)
# Out:
#   dates      line
# 1 2020-09-12 1495.000
# 2 2020-09-13 1573.634
# 3 2020-09-14 1656.405
# 4 2020-09-15 1743.529
# 5 2020-09-16 1835.235
# 6 2020-09-17 1931.765

# %%
q + geom_path(data=df_line,aes(x=dates,y=line), color="green" )
# Out:
# Warning message:
# "Transformation introduced infinite values in continuous y-axis"
# Warning message:
# "Transformation introduced infinite values in continuous y-axis"
# Warning message:
# "Removed 436 row(s) containing missing values (geom_path)."
# Warning message:
# "Removed 436 row(s) containing missing values (geom_path)."
# plot without title

# %% [markdown]
# # Aufgabe
# * Versucht anhand der logarithmierten Fallzahlen Zeiträume zu finden, für die exponentielles Wachstum plausibel erscheint.
# * Zeichnet die entsprechenden Plots und die geschätzten Wachstumsgeraden

# %% [markdown]
# # Neuer Datensatz
# Ladet euch die Daten des Portals "Our World in Data" runter:
#
# https://covid.ourworldindata.org/data/owid-covid-data.csv

# %%
df_owid <- read.csv("data/owid-covid-data.csv")
head(df_owid)
# Out:
#   iso_code continent location    date       total_cases new_cases
# 1 AFG      Asia      Afghanistan 2020-02-24 1           1
# 2 AFG      Asia      Afghanistan 2020-02-25 1           0
# 3 AFG      Asia      Afghanistan 2020-02-26 1           0
# 4 AFG      Asia      Afghanistan 2020-02-27 1           0
# 5 AFG      Asia      Afghanistan 2020-02-28 1           0
# 6 AFG      Asia      Afghanistan 2020-02-29 1           0
#   new_cases_smoothed total_deaths new_deaths new_deaths_smoothed ...
# 1    NA              NA           NA         NA                  ...
# 2    NA              NA           NA         NA                  ...
# 3    NA              NA           NA         NA                  ...
# 4    NA              NA           NA         NA                  ...
# 5    NA              NA           NA         NA                  ...
# 6 0.143              NA           NA          0                  ...
#   gdp_per_capita extreme_poverty cardiovasc_death_rate diabetes_prevalence
# 1 1803.987       NA              597.029               9.59
# 2 1803.987       NA              597.029               9.59
# 3 1803.987       NA              597.029               9.59
# 4 1803.987       NA              597.029               9.59
# 5 1803.987       NA              597.029               9.59
# 6 1803.987       NA              597.029               9.59
#   female_smokers male_smokers handwashing_facilities hospital_beds_per_thousand
# 1 NA             NA           37.746                 0.5
# 2 NA             NA           37.746                 0.5
# 3 NA             NA           37.746                 0.5
# 4 NA             NA           37.746                 0.5
# 5 NA             NA           37.746                 0.5
# 6 NA             NA           37.746                 0.5
#   life_expectancy human_development_index
# 1 64.83           0.511
# 2 64.83           0.511
# 3 64.83           0.511
# 4 64.83           0.511
# 5 64.83           0.511
# 6 64.83           0.511

# %%
colnames(df_owid)
# Out:
#  [1] "iso_code"
#  [2] "continent"
#  [3] "location"
#  [4] "date"
#  [5] "total_cases"
#  [6] "new_cases"
#  [7] "new_cases_smoothed"
#  [8] "total_deaths"
#  [9] "new_deaths"
# [10] "new_deaths_smoothed"
# [11] "total_cases_per_million"
# [12] "new_cases_per_million"
# [13] "new_cases_smoothed_per_million"
# [14] "total_deaths_per_million"
# [15] "new_deaths_per_million"
# [16] "new_deaths_smoothed_per_million"
# [17] "reproduction_rate"
# [18] "icu_patients"
# [19] "icu_patients_per_million"
# [20] "hosp_patients"
# [21] "hosp_patients_per_million"
# [22] "weekly_icu_admissions"
# [23] "weekly_icu_admissions_per_million"
# [24] "weekly_hosp_admissions"
# [25] "weekly_hosp_admissions_per_million"
# [26] "new_tests"
# [27] "total_tests"
# [28] "total_tests_per_thousand"
# [29] "new_tests_per_thousand"
# [30] "new_tests_smoothed"
# [31] "new_tests_smoothed_per_thousand"
# [32] "positive_rate"
# [33] "tests_per_case"
# [34] "tests_units"
# [35] "total_vaccinations"
# [36] "people_vaccinated"
# [37] "people_fully_vaccinated"
# [38] "new_vaccinations"
# [39] "new_vaccinations_smoothed"
# [40] "total_vaccinations_per_hundred"
# [41] "people_vaccinated_per_hundred"
# [42] "people_fully_vaccinated_per_hundred"
# [43] "new_vaccinations_smoothed_per_million"
# [44] "stringency_index"
# [45] "population"
# [46] "population_density"
# [47] "median_age"
# [48] "aged_65_older"
# [49] "aged_70_older"
# [50] "gdp_per_capita"
# [51] "extreme_poverty"
# [52] "cardiovasc_death_rate"
# [53] "diabetes_prevalence"
# [54] "female_smokers"
# [55] "male_smokers"
# [56] "handwashing_facilities"
# [57] "hospital_beds_per_thousand"
# [58] "life_expectancy"
# [59] "human_development_index"

# %% [markdown]
# Wir beschäftigen uns zunächst wieder mit Deutschland:

# %%
df_owid$date <- as.Date(df_owid$date)

# %%
ggplot(df_owid[df_owid$location=="Germany" & df_owid$date>="2021-01-01",]) +
    geom_path(aes(x=date,y=new_vaccinations_smoothed_per_million))
# Out:
# Warning message:
# "Removed 1 row(s) containing missing values (geom_path)."
# plot without title

# %%
ggplot(df_owid[df_owid$continent =="Europe" & df_owid$date>="2021-01-01",]) +
    geom_path(aes(x=date,y=new_vaccinations, color=location))
# Out:
# Warning message:
# "Removed 1934 row(s) containing missing values (geom_path)."
# plot without title

# %%
head(df_owid[df_owid$continent =="Europe" & df_owid$date>="2021-01-01",])
# Out:
#      iso_code continent location date       total_cases new_cases
# 1185 ALB      Europe    Albania  2021-01-01 58316         0
# 1186 ALB      Europe    Albania  2021-01-02 58991       675
# 1187 ALB      Europe    Albania  2021-01-03 59438       447
# 1188 ALB      Europe    Albania  2021-01-04 59623       185
# 1189 ALB      Europe    Albania  2021-01-05 60283       660
# 1190 ALB      Europe    Albania  2021-01-06 61008       725
#      new_cases_smoothed total_deaths new_deaths new_deaths_smoothed ...
# 1185 419.429            1181          0         6.714               ...
# 1186 462.286            1190          9         6.714               ...
# 1187 454.857            1193          3         5.714               ...
# 1188 435.857            1199          6         5.000               ...
# 1189 448.143            1210         11         5.714               ...
# 1190 468.714            1217          7         6.143               ...
#      gdp_per_capita extreme_poverty cardiovasc_death_rate diabetes_prevalence
# 1185 11803.43       1.1             304.195               10.08
# 1186 11803.43       1.1             304.195               10.08
# 1187 11803.43       1.1             304.195               10.08
# 1188 11803.43       1.1             304.195               10.08
# 1189 11803.43       1.1             304.195               10.08
# 1190 11803.43       1.1             304.195               10.08
#      female_smokers male_smokers handwashing_facilities
# 1185 7.1            51.2         NA
# 1186 7.1            51.2         NA
# 1187 7.1            51.2         NA
# 1188 7.1            51.2         NA
# 1189 7.1            51.2         NA
# 1190 7.1            51.2         NA
#      hospital_beds_per_thousand life_expectancy human_development_index
# 1185 2.89                       78.57           0.795
# 1186 2.89                       78.57           0.795
# 1187 2.89                       78.57           0.795
# 1188 2.89                       78.57           0.795
# 1189 2.89                       78.57           0.795
# 1190 2.89                       78.57           0.795

# %%
vacc_germany <- df_owid$new_vaccinations_smoothed_per_million[df_owid$location=="Germany" & df_owid$date>="2021-01-01"]
vacc_france <-  df_owid$new_vaccinations_smoothed_per_million[df_owid$location=="France" & df_owid$date>="2021-01-01"]
correlation_france <- cor(vacc_germany, vacc_france, use="pairwise.complete.obs")
cat(paste0("Vaccination correlation with France is ", correlation_france,"\nabcd"))
print("abc")
# Out:
# Vaccination correlation with France is 0.969660889018272
# abcd[1] "abc"

# %%
cat(paste0("Vaccination correlation with France is ", format(correlation_france*100,digits=4),"%\n"))

# %% [markdown]
# # Aufgabe
# * Stellt den Impffortschritt der zehn Länder weltweit mit der aktuell höchsten Impfquote in einem Plot dar.
# * Reproduziert den Plot für die zehn führenden Länder, die mehr als 5 Millionen Einwohner haben.
#
#
# * Berechnet die Korrelationen der Impfgeschwindigkeit mit Deutschland für alle europäischen Länder.
# * Erstellt einen Plot für die Impfungen pro eine Million Einwohner mit den fünf europäischen Ländern, die die höchste Korrelation haben. Färbt die Graphen entsprechend der Korrelation.

# %%
countries <- unique(df_owid$location)
vacc_progress <- sapply(countries,
            function(country)max(df_owid[df_owid$location==country,"total_vaccinations_per_hundred"], na.rm=T ) )
# Out:
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(df_owid[df_owid$location == country, "total_vaccinations_per_hundred"], :
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"

# %%
sort(vacc_progress,decreasing = TRUE)
# Out:
#                        Gibraltar                 Falkland Islands
#                           206.38                           126.53
#                       Seychelles                           Israel
#                           125.92                           121.09
#             United Arab Emirates                   Cayman Islands
#                           105.82                            99.49
#                          Bermuda                      Isle of Man
#                            89.77                            84.32
#                       San Marino                           Jersey
#                            83.90                            81.86
#                            Chile                     Saint Helena
#                            75.84                            75.31
#                            Malta                         Maldives
#                            74.04                            71.57
#                          Bahrain                   United Kingdom
#                            71.48                            70.91
#                    United States                            Aruba
#                            70.16                            69.94
#                         Guernsey         Turks and Caicos Islands
#                            69.48                            64.67
#                           Bhutan                           Monaco
#                            62.24                            62.15
#                          Hungary                          Curacao
#                            58.93                            54.69
#                            Qatar                           Serbia
#                            51.95                            50.12
#                          Uruguay                         Anguilla
#                            50.10                            45.98
#                    North America                   Faeroe Islands
#                            45.49                            41.42
#                       Montserrat                        Singapore
#                            38.19                            37.84
#                          Iceland                          Andorra
#                            35.61                            34.19
#                           Canada                        Lithuania
#                            33.98                            33.43
#                          Denmark                          Germany
#                            33.37                            33.19
#                          Austria                         Mongolia
#                            33.02                            32.96
#                            Spain                          Estonia
#                            32.89                            32.63
#                         Dominica                          Finland
#                            32.02                            31.71
#                   European Union                          Belgium
#                            31.37                            31.36
#                            Italy                      Netherlands
#                            31.26                            30.73
#                         Portugal              Antigua and Barbuda
#                            30.70                            30.38
#                           Sweden                           France
#                            30.34                            30.06
#                    Liechtenstein                           Norway
#                            30.04                            29.98
#                       Luxembourg                          Ireland
#                            29.79                            29.41
#                           Poland                           Europe
#                            29.28                            28.90
#                           Greece                  Northern Cyprus
#                            28.87                            28.65
#                         Slovenia                          Czechia
#                            28.53                            28.10
#                      Switzerland                         Slovakia
#                            28.10                            27.70
#                           Cyprus                           Turkey
#                            26.97                            26.24
#                         Barbados                          Romania
#                            25.68                            25.54
#                     Saudi Arabia                          Morocco
#                            25.41                            25.03
#                        Greenland                           Kuwait
#                            24.39                            23.42
#            Saint Kitts and Nevis                          Croatia
#                            22.27                            20.12
#                           Brazil                        Hong Kong
#                            19.29                            18.03
#               Dominican Republic                    South America
#                            17.03                            16.97
#                            China                        Argentina
#                            16.95                            16.72
#                           Guyana                       Costa Rica
#                            16.12                            16.08
#                            Macao                          Albania
#                            15.47                            15.07
#                           Latvia                           Panama
#                            14.99                            14.84
#                       Azerbaijan                            World
#                            14.36                            13.93
#                      Saint Lucia                           Russia
#                            13.14                            13.05
#                           Mexico                      El Salvador
#                            12.94                            12.86
#                         Cambodia Saint Vincent and the Grenadines
#                            12.67                            12.49
#                          Grenada                         Bulgaria
#                            11.34                            11.17
#                             Asia                            India
#                            10.92                            10.66
#                           Belize                       Montenegro
#                            10.31                             9.62
#                         Colombia                        Mauritius
#                             9.27                             9.23
#                        Australia                            Nepal
#                             7.96                             7.18
#                           Jordan                        Indonesia
#                             7.17                             7.15
#                       Kazakhstan                          Lebanon
#                             7.02                             6.67
#                         Suriname                          Bahamas
#                             6.54                             6.53
#                            Nauru                             Fiji
#                             6.46                             6.25
#                          Bolivia                             Oman
#                             6.19                             6.18
#                      South Korea                          Oceania
#                             5.81                             5.46
#                Equatorial Guinea                       Bangladesh
#                             5.38                             5.17
#                            Tonga                      New Zealand
#                             5.08                             4.82
#                          Ecuador                             Peru
#                             4.63                             4.60
#                          Jamaica            Sao Tome and Principe
#                             4.57                             4.44
#                        Sri Lanka                         Malaysia
#                             4.32                             4.23
#                        Palestine                          Belarus
#                             4.19                             3.48
#                          Moldova                         Zimbabwe
#                             3.46                             3.08
#                         Eswatini              Trinidad and Tobago
#                             3.01                             3.01
#                          Tunisia                            Ghana
#                             2.93                             2.72
#                           Rwanda                  North Macedonia
#                             2.70                             2.68
#                            Japan                             Laos
#                             2.55                             2.53
#                           Brunei                          Senegal
#                             2.45                             2.43
#                         Botswana                         Thailand
#                             2.01                             1.93
#                             Togo                          Myanmar
#                             1.93                             1.91
#                       Uzbekistan                      Philippines
#                             1.79                             1.65
#                            Kenya                           Malawi
#                             1.59                             1.49
#                         Paraguay                          Ukraine
#                             1.46                             1.44
#                           Angola                           Africa
#                             1.39                             1.31
#                           Kosovo                             Iran
#                             1.14                             1.12
#                          Georgia                         Djibouti
#                             1.05                             1.04
#                           Guinea                         Pakistan
#                             1.03                             0.95
#                        Guatemala                        Nicaragua
#                             0.94                             0.93
#                        Venezuela                           Gambia
#                             0.88                             0.87
#                          Namibia                          Lesotho
#                             0.79                             0.75
#                             Iraq                     Sierra Leone
#                             0.74                             0.74
#                          Somalia                  Solomon Islands
#                             0.74                             0.71
#                           Uganda                            Egypt
#                             0.66                             0.64
#                      Afghanistan                         Honduras
#                             0.62                             0.58
#                          Nigeria                    Cote d'Ivoire
#                             0.58                             0.50
#                     South Africa           Bosnia and Herzegovina
#                             0.50                             0.46
#                          Vietnam                            Gabon
#                             0.44                             0.40
#                       Cape Verde                         Ethiopia
#                             0.39                             0.37
#                            Sudan                            Congo
#                             0.32                             0.26
#                             Mali                           Taiwan
#                             0.25                             0.21
#                            Timor                       Mozambique
#                             0.20                             0.18
#                          Algeria                       Mauritania
#                             0.17                             0.15
#                           Zambia                       Kyrgyzstan
#                             0.12                             0.03
#                 Papua New Guinea                          Armenia
#                             0.03                             0.02
#                            Libya                            Niger
#                             0.01                             0.01
#                      South Sudan                            Syria
#                             0.01                             0.01
#                         Cameroon     Democratic Republic of Congo
#                             0.00                             0.00
#                            Benin                     Burkina Faso
#                             -Inf                             -Inf
#                          Burundi         Central African Republic
#                             -Inf                             -Inf
#                             Chad                          Comoros
#                             -Inf                             -Inf
#                             Cuba                          Eritrea
#                             -Inf                             -Inf
#                    Guinea-Bissau                            Haiti
#                             -Inf                             -Inf
#                    International                          Liberia
#                             -Inf                             -Inf
#                       Madagascar                 Marshall Islands
#                             -Inf                             -Inf
#             Micronesia (country)                            Samoa
#                             -Inf                             -Inf
#                       Tajikistan                         Tanzania
#                             -Inf                             -Inf
#                          Vanuatu                          Vatican
#                             -Inf                             -Inf
#                            Yemen
#                             -Inf

# %%
top_countries <- names(sort(vacc_progress,decreasing = TRUE))[1:10]
top_countries
# Out:
#  [1] "Gibraltar"            "Falkland Islands"     "Seychelles"
#  [4] "Israel"               "United Arab Emirates" "Cayman Islands"
#  [7] "Bermuda"              "Isle of Man"          "San Marino"
# [10] "Jersey"

# %%
ggplot( df_owid[df_owid$location %in% top_countries& df_owid$date>="2021-01-01", ] ) +
    geom_path(aes(x=date, y= total_vaccinations_per_hundred,color=location))
# Out:
# Warning message:
# "Removed 109 row(s) containing missing values (geom_path)."
# plot without title

# %%
library(magrittr)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
top_big_countries <- df_owid %>% filter(population>5e6) %>%
    group_by(location) %>%
    summarise(progress=max(total_vaccinations_per_hundred,na.rm=T)) %>% 
    top_n(10,wt = ) 
top_big_countries
# Out:
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
# Warning message in max(total_vaccinations_per_hundred, na.rm = T):
# "kein nicht-fehlendes Argument für max; gebe -Inf zurück"
#    location             progress
# 1  Canada                33.98
# 2  Chile                 75.84
# 3  Hungary               58.93
# 4  Israel               121.09
# 5  North America         45.49
# 6  Serbia                50.12
# 7  Singapore             37.84
# 8  United Arab Emirates 105.82
# 9  United Kingdom        70.91
# 10 United States         70.16

# %%
top_big_countries %<>% extract2("location")
top_big_countries
# Out:
#  [1] "Canada"               "Chile"                "Hungary"
#  [4] "Israel"               "North America"        "Serbia"
#  [7] "Singapore"            "United Arab Emirates" "United Kingdom"
# [10] "United States"

# %%
ggplot(df_owid %>% filter(location %in% top_big_countries, date>="2020-12-01"))+
    geom_path(aes(x=date,y=total_vaccinations_per_hundred,color=location))
# Out:
# Warning message:
# "Removed 281 row(s) containing missing values (geom_path)."
# plot without title

# %%
sort(df_countries$countries[df_countries$population>5e6],decreasing=TRUE)
# Out:
# NULL
